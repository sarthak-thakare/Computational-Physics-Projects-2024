# %% [markdown]
# # **Basic Python**

# %% [markdown]
# ## 1.a
# Give a function F that takes a single argument n. This function should print a sequence of n strings as described in the examples below: <br>
# Ex: **n = 3**
#
# --A--<br>
# -BAB-<br>
# CBABC<br>
#
# **n = 4**
#
# ---A---<br>
# --BAB--<br>
# -CBABC-<br>
# DCBABCD

# %%
def F(n):
    # Start coding
    for i in range(1,n+1):
        blank='-' * (n-i)
        alphabet=''.join(chr(65+j) for j in range(i))
        reverse=alphabet[:-1][::-1]
        row=blank+alphabet+reverse+blank
        print(row)
    pass

# Tests
F(10)
F(6)
# Out:
# ---------A---------
# --------ABA--------
# -------ABCBA-------
# ------ABCDCBA------
# -----ABCDEDCBA-----
# ----ABCDEFEDCBA----
# ---ABCDEFGFEDCBA---
# --ABCDEFGHGFEDCBA--
# -ABCDEFGHIHGFEDCBA-
# ABCDEFGHIJIHGFEDCBA
# -----A-----
# ----ABA----
# ---ABCBA---
# --ABCDCBA--
# -ABCDEDCBA-
# ABCDEFEDCBA

# %% [markdown]
# ## 1.b
# Make a function F that takes only one argument, a dictionary(dict) d.
# The keys of d are integers and the values of d are a tuple of type (x (int), y (int)).
# You must print out the dict in the format "-key-, -x-, -y-" with each entry in a new line. Print it for each of the three sorted orders, by key values ascending, by x values descending, by y values ascending.

# %%
def F(d : dict):
    # Start coding
    for key in sorted(d):
        print(f"{key}, {d[key][0]}, {d[key][1]}")

    print()
    for key in sorted(d, key=lambda k: d[k][0], reverse=True):     
        print(f"{key}, {d[key][0]}, {d[key][1]}")

    print()
    for key in sorted(d, key=lambda k: d[k][1]):        
        print(f"{key}, {d[key][0]}, {d[key][1]}")
    print()    
    pass

# Tests
F({1 : (1, 2), 2 : (-1, 4), 5 : (-4, 3), 4 : (2, 3)})
F({-8 : (4, 2), 6 : (-3, 4), 7 : (2, 1), 5 : (9, -10)})
# Out:
# 1, 1, 2
# 2, -1, 4
# 4, 2, 3
# 5, -4, 3
#
# 4, 2, 3
# 1, 1, 2
# 2, -1, 4
# 5, -4, 3
#
# 1, 1, 2
# 5, -4, 3
# 4, 2, 3
# 2, -1, 4
#
# -8, 4, 2
# 5, 9, -10
# 6, -3, 4
# 7, 2, 1
#
# 5, 9, -10
# -8, 4, 2
# 7, 2, 1
# 6, -3, 4
#
# 5, 9, -10
# 7, 2, 1
# -8, 4, 2
# 6, -3, 4

# %% [markdown]
# ## 2 Working with Student Records
#
# Use the data in **student_records.csv** to complete the given tasks. Do not include any external libraries. Use a Python dictionary if required.
#
# ### Reference
# - [Python Dictionaries](https://www.w3schools.com/python/python_dictionaries.asp)

# %% [markdown]
# #### 2.a: open the student_records.csv file and print out the first 10 rows

# %%
#TODO
with open('student_records.csv','r') as file:

    for i in range(10):
        line=file.readline().strip()
        if not line:
            break
        print(line)
# Out:
# roll_number,department,credit,course_name,course_type,grade
# 588946,MA,3,EC250,hasmed_elective,AB
# 145372,EP,4,EP407,hasmed_elective,CC
# 834515,MA,8,EP885,hasmed_elective,BB
# 344265,CSE,6,CSE699,honours,AB
# 358405,MA,3,EE460,minor,AP
# 781075,CE,8,CE540,honours,CC
# 180828,CSE,6,CE880,minor,AB
# 981238,MM,4,CSE226,minor,AB
# 836881,MM,8,MM530,core,AA

# %% [markdown]
# #### 2.b: Print out the total credits and calculte CPI of each student.
# CPI is the weighted average of core courses, and electives (weights being the letter grades converted to number AP,AA=10, AB=9, BB=8, BC=7, CC=6)

# %%
#TODO
grade_to_credits = {
    'AA': 10,
    'AP': 10,
    'AB': 9,
    'BB': 8,
    'BC': 7,
    'CC': 6
}

students_data = {}
CPI={}

with open('student_records.csv','r') as file:
    next(file)

    for line in file:
        data = line.strip().split(',')
        roll_number = data[0]
        department = data[1]
        credits = int(data[2])
        course_name = data[3]
        course_type = data[4]
        grade = data[5]

        grade_credits=grade_to_credits.get(grade)   


        if roll_number not in students_data:
            students_data[roll_number] = {
                'total_credits': 0,
                'weighted_grade_points': 0
            }
        
        students_data[roll_number]['total_credits'] += credits
        students_data[roll_number]['weighted_grade_points'] += credits * grade_credits

        CPI[roll_number]=students_data[roll_number]['weighted_grade_points']/students_data[roll_number]['total_credits'] 
for roll_number in students_data:
    print(f"{roll_number},{students_data[roll_number]['total_credits']},{CPI[roll_number]}")
# Out:
# 588946,199,8.693467336683417
# 145372,173,7.745664739884393
# 834515,199,8.21608040201005
# 344265,153,8.699346405228757
# 358405,206,8.587378640776699
# 781075,246,8.170731707317072
# 180828,177,8.096045197740112
# 981238,168,8.244047619047619
# 836881,246,8.386178861788618
# 310604,198,8.333333333333334
# 847809,261,8.210727969348659
# 773982,264,8.068181818181818
# 500658,208,8.16826923076923
# 810863,192,8.151041666666666
# 124663,229,8.126637554585153
# 364146,225,8.395555555555555
# 871746,216,8.212962962962964
# 270007,241,8.033195020746888
# 597353,200,8.12
# 986057,199,8.06532663316583
# 718510,184,8.429347826086957
# 836431,160,7.9
# 379479,260,8.246153846153845
# 582912,221,8.656108597285067
# 788020,193,8.015544041450777
# 613401,209,8.440191387559809
# 144528,228,8.157894736842104
# 485484,216,8.36111111111111
# 680096,153,8.045751633986928
# 199713,172,8.290697674418604
# 851029,161,8.322981366459627
# 845623,237,8.375527426160337
# 150503,173,8.289017341040463
# ...

# %% [markdown]
# #### 2.c: Print out the roll numbers of all students who meet the graduation requirements
# Atleast 20 credist of core course, 15 credits of department elective, 10 credits of flexible elective and 5 credits of hasmed electives

# %%
#TODO
grade_to_credits = {
    'AA': 10,
    'AP': 10,
    'AB': 9,
    'BB': 8,
    'BC': 7,
    'CC': 6
}

students_data = {}
CPI={}

with open('student_records.csv','r') as file:
    next(file)

    for line in file:
        data = line.strip().split(',')
        roll_number = data[0]
        department = data[1]
        credits = int(data[2])
        course_name = data[3]
        course_type = data[4]
        grade = data[5]

        grade_credits=grade_to_credits.get(grade)   


        if roll_number not in students_data:
            students_data[roll_number] = {
                'total_credits': 0,
                'weighted_grade_points': 0,
                'no_of_core_courses':0,
                'no_of_department_electives':0,
                'no_of_flexible_electives':0,
                'no_of_hasmed_electives':0,
                'no_of_minor':0
            }
        
        students_data[roll_number]['total_credits'] += credits
        students_data[roll_number]['weighted_grade_points'] += credits * grade_credits
        if course_type == 'hasmed_elective':
            students_data[roll_number]['no_of_hasmed_electives']+=credits
        elif course_type == 'department_elective':
            students_data[roll_number]['no_of_department_electives']+=credits
        elif course_type == 'flexible_elective':
            students_data[roll_number]['no_of_flexible_electives']+=credits
        elif course_type == 'core':
            students_data[roll_number]['no_of_core_courses']+=credits
        elif course_type == 'minor':
            students_data[roll_number]['no_of_minor']+=credits
        else:
            continue

        CPI[roll_number]=students_data[roll_number]['weighted_grade_points']/students_data[roll_number]['total_credits'] 

for roll_number in students_data:
    if students_data[roll_number]['no_of_core_courses'] >=20 and students_data[roll_number]['no_of_hasmed_electives']>=5 and students_data[roll_number]['no_of_department_electives']>=15 and students_data[roll_number]['no_of_flexible_electives']>=10:
        print(roll_number)
# Out:
# 588946
# 834515
# 781075
# 180828
# 981238
# 836881
# 310604
# 773982
# 500658
# 810863
# 124663
# 871746
# 986057
# 379479
# 144528
# 485484
# 845623
# 150503
# 214270
# 517837
# 482623
# 721490
# 955757
# 143856
# 571782
# 973158
# 703403
# 960395
# 521087
# 461971
# 879634
# 716985
# 265922
# 283796
# 203200
# 327122
# 534763
# 391848
# 971123
# 207443
# 488661
# 782129
# 928288
# 581858
# 282482
# 572815
# 608952
# 628849
# 630568
# 388969
# 159438
# 970791
# 143142
# 998293
# 681499
# 888886
# 608522
# 362471
# 692318
# 626000
# 581065
# 787967
# 381227
# 750259
# 881983
# 294697

# %% [markdown]
# #### 2.d: Print out the roll numbers of all students who completed a minor
# Atleast 10 credits with minor tag in a specific department

# %%
#TODO
grade_to_credits = {
    'AA': 10,
    'AP': 10,
    'AB': 9,
    'BB': 8,
    'BC': 7,
    'CC': 6
}

students_data = {}
CPI={}

with open('student_records.csv','r') as file:
    next(file)

    for line in file:
        data = line.strip().split(',')
        roll_number = data[0]
        department = data[1]
        credits = int(data[2])
        course_name = data[3]
        course_type = data[4]
        grade = data[5]

        grade_credits=grade_to_credits.get(grade)   


        if roll_number not in students_data:
            students_data[roll_number] = {
                'total_credits': 0,
                'weighted_grade_points': 0,
                'no_of_core_courses':0,
                'no_of_department_electives':0,
                'no_of_flexible_electives':0,
                'no_of_hasmed_electives':0,
                'no_of_minor':0
            }
        
        students_data[roll_number]['total_credits'] += credits
        students_data[roll_number]['weighted_grade_points'] += credits * grade_credits
        if course_type == 'hasmed_elective':
            students_data[roll_number]['no_of_hasmed_electives']+=credits
        elif course_type == 'department_elective':
            students_data[roll_number]['no_of_department_electives']+=credits
        elif course_type == 'flexible_elective':
            students_data[roll_number]['no_of_flexible_electives']+=credits
        elif course_type == 'core':
            students_data[roll_number]['no_of_core_courses']+=credits
        elif course_type == 'minor':
            students_data[roll_number]['no_of_minor']+=credits
        else:
            continue

        CPI[roll_number]=students_data[roll_number]['weighted_grade_points']/students_data[roll_number]['total_credits'] 

for roll_number in students_data:
    if students_data[roll_number]['no_of_minor'] >=10:
        print(roll_number)
# Out:
# 588946
# 145372
# 834515
# 344265
# 358405
# 781075
# 180828
# 981238
# 836881
# 847809
# 773982
# 500658
# 810863
# 124663
# 364146
# 871746
# 270007
# 597353
# 986057
# 718510
# 836431
# 379479
# 582912
# 788020
# 613401
# 144528
# 485484
# 680096
# 199713
# 851029
# 845623
# 150503
# 214270
# 517837
# 482623
# 721490
# 955757
# 143856
# 571782
# 973158
# 703403
# 960395
# 521087
# 461971
# 879634
# 716985
# 194063
# 265922
# 283796
# 203200
# 301135
# 327122
# 381526
# 534763
# 391848
# 329535
# 971123
# 207443
# 488661
# 782129
# 581858
# 733782
# 282482
# 572815
# 608952
# 628849
# 630568
# 388969
# 159438
# 478606
# 995208
# 841365
# 970791
# 143142
# 998293
# 907454
# 681499
# 888886
# 608522
# 362471
# 465496
# 208100
# 138296
# 775967
# 692318
# 461584
# 626000
# 458200
# 581065
# 787967
# 381227
# 750259
# 881983
# 294697
# 816041
# 993835

# %% [markdown]
# #### 2.e: Print out the roll numbers of all students who completed a honours
# Atleast 10 credits with honours tag and 20 core credits

# %%
#TODO
grade_to_credits = {
    'AA': 10,
    'AP': 10,
    'AB': 9,
    'BB': 8,
    'BC': 7,
    'CC': 6
}

students_data = {}
CPI={}

with open('student_records.csv','r') as file:
    next(file)

    for line in file:
        data = line.strip().split(',')
        roll_number = data[0]
        department = data[1]
        credits = int(data[2])
        course_name = data[3]
        course_type = data[4]
        grade = data[5]

        grade_credits=grade_to_credits.get(grade)   


        if roll_number not in students_data:
            students_data[roll_number] = {
                'total_credits': 0,
                'weighted_grade_points': 0,
                'no_of_core_courses':0,
                'no_of_department_electives':0,
                'no_of_flexible_electives':0,
                'no_of_hasmed_electives':0,
                'no_of_minor':0,
                'no_of_honour':0
            }
        
        students_data[roll_number]['total_credits'] += credits
        students_data[roll_number]['weighted_grade_points'] += credits * grade_credits
        if course_type == 'hasmed_elective':
            students_data[roll_number]['no_of_hasmed_electives']+=credits
        elif course_type == 'department_elective':
            students_data[roll_number]['no_of_department_electives']+=credits
        elif course_type == 'flexible_elective':
            students_data[roll_number]['no_of_flexible_electives']+=credits
        elif course_type == 'core':
            students_data[roll_number]['no_of_core_courses']+=credits
        elif course_type == 'minor':
            students_data[roll_number]['no_of_minor']+=credits
        elif course_type == 'honours':
            students_data[roll_number]['no_of_honour']+=credits
        else:
            continue

        CPI[roll_number]=students_data[roll_number]['weighted_grade_points']/students_data[roll_number]['total_credits'] 

for roll_number in students_data:
    if students_data[roll_number]['no_of_honour'] >=10 and students_data[roll_number]['no_of_core_courses']>=20:
        print(roll_number)
# Out:
# 588946
# 145372
# 834515
# 781075
# 836881
# 310604
# 773982
# 500658
# 810863
# 124663
# 364146
# 871746
# 986057
# 718510
# 379479
# 582912
# 788020
# 613401
# 144528
# 485484
# 199713
# 845623
# 150503
# 214270
# 517837
# 482623
# 721490
# 955757
# 589528
# 143856
# 571782
# 973158
# 703403
# 960395
# 521087
# 461971
# 879634
# 716985
# 265922
# 283796
# 203200
# 327122
# 534763
# 391848
# 971123
# 207443
# 488661
# 782129
# 928288
# 581858
# 282482
# 572815
# 608952
# 628849
# 630568
# 388969
# 159438
# 870642
# 970791
# 143142
# 998293
# 681499
# 888886
# 608522
# 362471
# 465496
# 208100
# 692318
# 626000
# 458200
# 581065
# 787967
# 750259
# 881983
# 294697

# %% [markdown]
# # **SciPy**

# %% [markdown]
# ## Part A
# Minimize the function $f(x, y) = 2(x - y - 3)^2 + 4(x + 2y + 1)^4$.<br>
# With the constraints : $ x - y \ge -3, (x + 2)^2 + (y + 1)^2 \le 5$ <br>
# Using scipy.optimize.minimize with constraints. (Hint: Look at the examples in the official documentation)

# %%
#TODO
from scipy.optimize import minimize

def objective(x):
    return 2 * (x[0] - x[1] - 3)**2 + 4 * (x[0] + 2 * x[1] + 1)**4

def constraint1(x):
    return x[0] - x[1] + 3  # x - y + 3 >= 0

def constraint2(x):
    return 5 - ((x[0] + 2)**2 + (x[1] + 1)**2)  # (x + 2)^2 + (y + 1)^2 <= 5

x0 = [0, 0]


con1 = {'type': 'ineq', 'fun': constraint1}
con2 = {'type': 'ineq', 'fun': constraint2}


result = minimize(objective, x0, method='trust-constr', constraints=[con1, con2])


print("Optimal solution:", result.x)
print("Objective value at the solution:", result.fun)
# Out:
# Optimal solution: [ 0.23492503 -0.92851485]
# Objective value at the solution: 7.345026227333165

# %% [markdown]
# # Part B
# Evaluate the line integral of the function $f(x, y) = x^2 + y^4$ along the circle $ x^2 + y^2 = 3 $ anticlockwise (scalar integral, not vector). You must use scipy for integration but you may use parameterization

# %%
import numpy as np
from scipy.integrate import quad

def x(t):
    return np.sqrt(3) * np.cos(t)

def y(t):
    return np.sqrt(3) * np.sin(t)


def integrand(t):
  
    xt = x(t)
    yt = y(t)
    f_xy = xt**2 + yt**4
    
    # ds = sqrt(dx/dt^2 + dy/dt^2) dt
    # dx/dt = -sqrt(3) sin(t), dy/dt = sqrt(3) cos(t)
    ds_dt = np.sqrt(3)  # since sqrt((-sqrt(3)sin(t))^2 + (sqrt(3)cos(t))^2) = sqrt(3)
    
    return f_xy * ds_dt


result,error= quad(integrand, 0, 2 * np.pi)

# Step 4: Print the result of the line integral
print(result)
# Out:
# 53.05363140385085

# %% [markdown]
# # **Numpy**

# %% [markdown]
# ### Read Lisan_Al_Gaib.pdf for problem description and complete the following functions

# %%
import time # to time the execution
import numpy as np
import matplotlib.pyplot as plt

# %%
### TODO 1
### Load data from data_path
### Check the input file spice_locations.txt to understand the Data Format
### Return : np array of size Nx2
def load_data(data_path):
    data = np.loadtxt(data_path, delimiter=',')
    return data

# %%
### TODO 2.1
### If init_centers is None, initialize the centers by selecting K data points at random without replacement
### Else, use the centers provided in init_centers
### Return : np array of size Kx2
def initialise_centers(data, K, init_centers=None):

    if init_centers is None:
        indices = np.random.choice(data.shape[0], size=K, replace=False)
        centers = data[indices]
    else:
        centers = init_centers

    return centers

# %%
### TODO 2.2
### Initialize the labels to all ones to size (N,) where N is the number of data points
### Return : np array of size N
def initialise_labels(data):
    
    N=data.shape[0]
    labels=np.ones(N)

    return labels

# %%
### TODO 3.1 : E step
### For Each data point, find the distance to each center
### Return : np array of size NxK
def calculate_distances(data, centers):
    N = data.shape[0]  
    K = centers.shape[0]  

    # Use broadcasting to compute pairwise Euclidean distances between data points and centers
    diff = data[:, np.newaxis, :] - centers  
    distances = np.sqrt(np.sum(diff**2, axis=2))  
    
    return distances

# %%
### TODO 3.2 : E step
### For Each data point, assign the label of the nearest center
### Return : np array of size N
def update_labels(distances):
    labels=np.argmin(distances, axis=1)
    return labels

# %%
### TODO 4 : M step
### Update the centers to the mean of the data points assigned to it
### Return : np array of size Kx2
def update_centers(data, labels, K):
    new_centers = np.zeros((K, 2))

    for k in range(K):
        points = data[labels == k]
        new_centers[k] = np.mean(points, axis=0)
    return new_centers

# %%
### TODO 6 : Check convergence
### Check if the labels have changed from the previous iteration
### Return : True / False
def check_termination(labels1, labels2):
    
    return np.array_equal(labels1, labels2)

# %%
### DON'T CHANGE ANYTHING IN THE FOLLOWING FUNCTION
def kmeans(data_path:str, K:int, init_centers):
    '''
    Input :
        data (type str): path to the file containing the data
        K (type int): number of clusters
        init_centers (type numpy.ndarray): initial centers. shape = (K, 2) or None
    Output :
        centers (type numpy.ndarray): final centers. shape = (K, 2)
        labels (type numpy.ndarray): label of each data point. shape = (N,)
        time (type float): time taken by the algorithm to converge in seconds
    N is the number of data points each of shape (2,)
    '''
    data = load_data(data_path)    
    centers = initialise_centers(data, K, init_centers)
    labels = initialise_labels(data)

    start_time = time.time() # Time stamp 

    while True:
        distances = calculate_distances(data, centers)
        labels_new = update_labels(distances)
        centers = update_centers(data, labels_new, K)
        if check_termination(labels, labels_new): break
        else: labels = labels_new
 
    end_time = time.time() # Time stamp after the algorithm ends
    return centers, labels, end_time - start_time

# %%
### TODO 7
def visualise(data_path, labels, centers):
    data = load_data(data_path)

    # Scatter plot of the data points
    plt.scatter(data[:, 0], data[:, 1], c=labels, s=50, cmap='viridis')
    plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

    ### Set title as 'K-means clustering'
    plt.title("K-means clustering")
    ### Set xlabel as 'Longitude'
    plt.xlabel("longitude")
    ### Set ylabel as 'Latitude'
    plt.ylabel("latitude")
    ### Save the plot as 'kmeans.png'
    plt.savefig("kmeans.png")

    ## DO NOT CHANGE THE FOLLOWING LINE
    return plt

# %%
### After you have completed the above functions, run the following code to generate the plot
data_path = 'spice_locations.txt'
K, init_centers = 2, None
centers, labels, time_taken = kmeans(data_path, K, init_centers)
print('Time taken for the algorithm to converge:', time_taken)
visualise(data_path, labels, centers)
# Out:
# Time taken for the algorithm to converge: 0.0
# <module 'matplotlib.pyplot' from 'c:\\Users\\sarth\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>
